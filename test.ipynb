# %%
import pandas as pd

df = pd.read_csv("dataset/book-crossing/preprocessed/book-crossing-2024-09-09.csv")
df
# Out:
# C:\Users\minhh\AppData\Local\Temp\ipykernel_10900\2386795078.py:3: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("dataset/book-crossing/preprocessed/book-crossing-2024-09-09.csv")
#              isbn country_code language_code  asin  is_ebook  average_rating  \
# 0      0001053744           US           NaN   NaN     False            3.90
# 1      0001821504           US           eng   NaN     False            4.13
# 2      0001837397           US           NaN   NaN     False            4.43
# 3      000184251X           US           NaN   NaN     False            4.50
# 4      0001981625           US           eng   NaN     False            3.57
# ...           ...          ...           ...   ...       ...             ...
# 52978  9997410440           US           eng   NaN     False            3.75
# 52979  9997412958           US           NaN   NaN     False            3.99
# 52980  9997531590           US           NaN   NaN     False            4.02
# 52981  9997555627           US           eng   NaN     False            4.37
# 52982  9999669972           US           NaN   NaN     False            3.78
#
#       kindle_asin                                        description  \
# 0             NaN  This 14th-century poem, translated into modern...
# 1             NaN  The Adventures of Paddingtonis a special editi...
# 2      B00830SQX2  Step into the exquisite miniature world of the...
# 3             NaN  Augustus Callendar, a newspaper correspondent,...
# 4             NaN  Leading up to the 40th anniversary of the firs...
# ...           ...                                                ...
# 52978         NaN  "This is a terrifying, yet inspiring novel. As...
# 52979         NaN  Romantic tale set in 17th-century England, whe...
# 52980  B018V77ID0  World's End is the first novel in Upton Sincla...
# 52981         NaN  Five-year-old Zeze lives in Rio de Janeiro, in...
# 52982         NaN  Help Me Be Good About Being Bullied explains w...
#
#           format                     publisher  ...   book_id  ratings_count  \
# 0      Audiobook              HarperCollins UK  ...   2654759             30
# 1      Hardcover                           NaN  ...   1254531            203
# 2      Hardcover  HarperCollinsChildren'sBooks  ...    529155             34
# 3            NaN                           NaN  ...   2596500             20
# 4      Hardcover      HarperCollins Publishers  ...   2159572             83
# ...          ...                           ...  ...       ...            ...
# 52978  Hardcover             Random House (NY)  ...    580970             51
# 52979        NaN                           NaN  ...   3727139             10
# 52980        NaN                           NaN  ...    204390            298
# 52981  Hardcover                           NaN  ...     46571            685
# 52982  Hardcover                           NaN  ...  12189298             12
#
#                                       title  \
# 0                       Pearl and Sir Orfeo
# 1              The Adventures of Paddington
# 2                              Autumn Story
# 3      February's Road (Callendars, Book 2)
# 4                    The Sea Of Tranquility
# ...                                     ...
# 52978                    Nine Hours to Rama
# 52979                       The White Witch
# 52980                           World's End
# 52981                  My Sweet Orange Tree
# 52982                         Being Bullied
#
#                        title_without_series            categories  \
# 0                       Pearl and Sir Orfeo            ['Poetry']
# 1              The Adventures of Paddington          ['Children']
# 2                              Autumn Story          ['Children']
# 3      February's Road (Callendars, Book 2)          ['Children']
# 4                    The Sea Of Tranquility          ['Children']
# ...                                     ...                   ...
# 52978                    Nine Hours to Rama  ['History, Biology']
# 52979                       The White Witch  ['History, Biology']
# 52980                           World's End  ['History, Biology']
# 52981                  My Sweet Orange Tree          ['Children']
# 52982                         Being Bullied          ['Children']
#
#                          authors             publisher_backup  \
# 0               J. R. R. Tolkien  Trafalgar Square Publishing
# 1                   Michael Bond     HarperCollins Publishers
# 2                   Jill Barklem  William Collins Sons Co Ltd
# 3                    John Verney     HarperCollins Publishers
# 4                    Mark Haddon     HarperCollins Publishers
# ...                          ...                          ...
# 52978            Stanley Wolpert             Random House (T)
# 52979           Elizabeth Goudge         Putnam Pub Group (T)
# 52980             Upton Sinclair              Penguin USA (T)
# 52981  Jose Mauro De Vasconcelos             Random House (T)
# 52982                  Joy Berry                Smithmark Pub
#
#                                         image_url_backup  \
# 0      http://images.amazon.com/images/P/0001053744.0...
# 1      http://images.amazon.com/images/P/0001821504.0...
# 2      http://images.amazon.com/images/P/0001837397.0...
# 3      http://images.amazon.com/images/P/000184251X.0...
# 4      http://images.amazon.com/images/P/0001981625.0...
# ...                                                  ...
# 52978  http://images.amazon.com/images/P/9997410440.0...
# 52979  http://images.amazon.com/images/P/9997412958.0...
# 52980  http://images.amazon.com/images/P/9997531590.0...
# 52981  http://images.amazon.com/images/P/9997555627.0...
# 52982  http://images.amazon.com/images/P/9999669972.0...
#
#        publication_year_backup  \
# 0                         1999
# 1                         1970
# 2                            0
# 3                         1987
# 4                         1996
# ...                        ...
# 52978                     1962
# 52979                     1958
# 52980                     1940
# 52981                     1971
# 52982                     1989
#
#                                 preprocessed_description
# 0      century poem translated modern english tolkien...
# 1      adventure paddingtonis special edition contain...
# 2      step exquisite miniature world mouse brambly h...
# 3      augustus callendar newspaper correspondent cri...
# 4      leading anniversary first moon landing excitem...
# ...                                                  ...
# 52978  terrifying yet inspiring novel nine fateful ho...
# 52979  romantic tale set century england cavalier str...
# 52980  world end first novel upton sinclair lanny bud...
# 52981  five year old zeze life rio janeiro forgotten ...
# 52982  help good bullied explains child bully others ...
#
# [52983 rows x 28 columns]

# %%
df = df.iloc[7:8]
df
# Out:
#          isbn country_code language_code  asin  is_ebook  average_rating  \
# 7  0002113570           US         en-US   NaN     False            4.33
#
#   kindle_asin                                        description     format  \
# 7         NaN  Valkoinen tytto simpanssien parissa viidakossa...  Hardcover
#
#   publisher  ...  book_id  ratings_count                 title  \
# 7   Collins  ...  2657522             43  In the Shadow of Man
#
#    title_without_series            categories       authors publisher_backup  \
# 7  In the Shadow of Man  ['History, Biology']  Jane Goodall          Collins
#
#                                     image_url_backup  publication_year_backup  \
# 7  http://images.amazon.com/images/P/0002113570.0...                     1971
#
#                             preprocessed_description
# 7  valkoinen tytto simpanssien parissa viidakossa...
#
# [1 rows x 28 columns]

# %%
import re

categories = df["categories"].values[0]
categories = re.sub(r"[^\w\s,]", "", categories)
print(categories)
# Out:
# History, Biology
